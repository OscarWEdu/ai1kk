# %% [markdown]
# ## Chapter 2

# %% [markdown]
# # Theory-questions

# %% [markdown]
# 1. I kapitlet beskrivs en checklista med sju steg. Beskriv de sju stegen över-
# siktligt. I verkligheten, följs dessa steg i en rak progression eller arbetar man generellt sett mer iterativt?

# %% [markdown]
#     1. Define the problem
#     2. Access the data
#     3. Perform an exploratory data analysis, used to determine if ML is needed, and discover potential paterns which may be useful when managing the data in the subsequent step.
#     4. Process the data. Decide which columns and datapoints are useful for training, as well as how to manage missing data and outliers.
#     5. Train the ML model. Decide on the most suitable model, hyperparameters, and perform the training.
#     6. Present your results of the model.
#     7. Put the model into production.

# %% [markdown]
# 2. Vad menas med att en modell produktionssätts?

# %% [markdown]
# That the model is in a stage where it is being used for its intended purpose. It may still be improved iteratively in some cases.

# %% [markdown]
# 3. Vad är scikit-learn för något? Biblioteket följer några centrala designprin-
# ciper. Vilka är dessa? Vad är estimators, predictors och transformers?

# %% [markdown]
# It's a data-analysis library, which provides functions for machine learning.
# The scikit estimator is the object used for learning from data, while a predictor is a specific estimator, which can use the estimation to perform prediction. A transformer is an estimator which modifies the input data.

# %% [markdown]
# 4. Vad är TensorFlow och Keras?

# %% [markdown]
# Tensorflow is another ML library, and so is Keras.

# %% [markdown]
# 5. Kalle och Stina diskuterar maskininlärning över en lunch. Kalle säger “om
# jag tränat en modell och den inte presterar bra nog på testdatan så justerar
# jag den tills den gör det.” Stina säger “det är ett stort fel att göra så, det
# enda du då åstadkommer är att du överanpassar testdatan. Hela syftet
# med testdatan försvinner då”. Vad säger du om deras dialog?

# %% [markdown]
# Since the model is not being trained on the test-data, modifying the hyperparameters and changing which training model used until you have one which is better at predicting the test-data is very logical. Stina does however also have a point that there can potentially be a bias towards specifically the test-data, if it is being adjusted specifically for it, which a reason for why we typically leave a section of the data to be used for validation, before being tested on the test-data.

# %% [markdown]
# 6. Många AI/ML projekt uppnår inte de ursprungligen satta målen eller att
# ens passera någon form av prototyp-stadie. Vad tror du detta beror på och
# hur ska vi förhålla oss till det?

# %% [markdown]
# There can be several reasons, one reason being that the Exploratory Data Analysis shows that the desired analysis can be performed through standard data analysis. Besides this, a ML model not reaching the desired results can be caused by bad or incomplete data, insufficient models, insufficient skills, or funds, etc. The failure emerging when the goal is is incompatible with the reality of the environment and factors the model is being developed in.
# What needs to be done to relate to this is to keep the low rate of success in mind before undertaking a venture using ML, and keep in mind existing limitations at the start of the project.

# %% [markdown]
# ## Code Questions

# %% [markdown]
# 7. Gå igenom samtliga kodexempel i kapitlet och skriv gärna av koden ma-
# nuellt. Det är även bra att experimentera genom att ändra vissa delar av
# koden och läsa dokumentationen.

# %% [markdown]
# Hashtag thumbs up

# %% [markdown]
# 8. Förklara vad koden nedan gör. Varför är det viktigt att kunna spara en
# modell?

# %%
#from sklearn.datasets import make_regression
#from sklearn.linear_model import LinearRegression
#from joblib import dump, load

#X, y = make_regression(n_samples=20000, n_features=3,
#noise=0.1)↪
#model = LinearRegression().fit(X, y)
#dump(model, "linear_model.joblib")
#model_loaded = load("linear_model.joblib")
#print(model_loaded.predict(X[:5])

# %% [markdown]
# We dump and then load the model using joblib, providing the model object, then loading the saved model to a new object.
# This is done to prevent needing to retrain the model each time we want to make use of it.

# %% [markdown]
# 9. Denna uppgift består av flera steg enligt nedan.
#
# a) Läs in datasetet “data_01.csv” med funktionen read_csv() från Pandas. Funktionen returnerar en DataFrame.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import root_mean_squared_error, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

dataset = pd.read_csv(r'C:data_01.csv')

dataset.head()
# Out:
#          x1        x2        x3        x4        x5      target
# 0  0.743487  1.072825  1.332911 -1.244771  0.344978  220.173943
# 1  0.835264  0.202184  0.966480  0.745883 -0.033773  175.873929
# 2 -1.103234  0.030615 -0.140385  0.727683 -2.831224 -162.270054
# 3  1.210186  1.685258 -0.394123  0.719024 -2.166585  165.930461
# 4  0.474577  0.647737 -0.451812 -0.409472 -0.051473   43.250511

# %% [markdown]
# b) Dela upp datasetet i X och y.

# %%
X = dataset.drop(columns=['target'])
y = dataset['target']

print(y.head())
print(X.head())
# Out:
# 0    220.173943
# 1    175.873929
# 2   -162.270054
# 3    165.930461
# 4     43.250511
# Name: target, dtype: float64
#          x1        x2        x3        x4        x5
# 0  0.743487  1.072825  1.332911 -1.244771  0.344978
# 1  0.835264  0.202184  0.966480  0.745883 -0.033773
# 2 -1.103234  0.030615 -0.140385  0.727683 -2.831224
# 3  1.210186  1.685258 -0.394123  0.719024 -2.166585
# 4  0.474577  0.647737 -0.451812 -0.409472 -0.051473

# %% [markdown]
# c) Dela upp datan ytterligare, i ett träning-, ett validering-, och ett testsetmed train_test_split(). Låt 20% av datan vara testdata och 15% av den återstående datan vara valideringsdata.

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.15, random_state=26)

print(X_train.shape)
print(y_train.shape)
# Out:
# (135, 5)
# (135,)

# %% [markdown]
# d) Träna två valfria regressionsmodeller (exempelvis LinearRegression och DecisionTreeRegressor) på träningsdatan. Notera, i kapitel 3 kommer vi lära oss mer om DecisionTreeRegressor.

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
lin_reg_pred = lin_reg.predict(X_val)

# %%
tree_reg = DecisionTreeRegressor(random_state=42)

# Find the best hyperparameter through GridSearch.
hyper_params = {'max_depth': (None, 1, 2, 3, 5, 10)}
reg = GridSearchCV(
    tree_reg,
    hyper_params,
    scoring='neg_root_mean_squared_error',
    cv=5
)

reg.fit(X_train, y_train)
tree_reg_pred = reg.predict(X_val)

# %%
print(reg.best_params_)
pd.DataFrame(reg.cv_results_)
# Out:
# {'max_depth': 10}
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.008671      0.000893         0.005339        0.000904
# 1       0.005988      0.000797         0.004107        0.000891
# 2       0.005158      0.001144         0.003290        0.000198
# 3       0.004917      0.000484         0.003508        0.000533
# 4       0.005121      0.000584         0.003965        0.000908
# 5       0.006564      0.000511         0.004378        0.000445
#
#   param_max_depth               params  split0_test_score  split1_test_score  \
# 0            None  {'max_depth': None}         -97.510952        -110.668896
# 1               1     {'max_depth': 1}         -90.512857        -123.475654
# 2               2     {'max_depth': 2}         -99.990635        -102.085267
# 3               3     {'max_depth': 3}        -110.659004        -100.888021
# 4               5     {'max_depth': 5}         -86.078501        -103.864217
# ...

# %% [markdown]
# e) Utvärdera modellerna på valideringsdatan.

# %%
def regression_metrics(y_true, y_pred):
    return {
        'MAE': mean_absolute_error(y_true, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred))
    }

validation_results = pd.DataFrame({
    'Linear Regression': regression_metrics(y_val, lin_reg_pred),
    'Decision Tree': regression_metrics(y_val, tree_reg_pred)
}).T

validation_results
# Out:
#                          MAE       RMSE
# Linear Regression   2.798756   3.814371
# Decision Tree      68.830817  88.511555

# %% [markdown]
# f) Träna om den bäst presterande modellen på både tränings- och validerings-datan.

# %%
lin_reg_final = LinearRegression().fit(X_train_full, y_train_full)
pred_test = lin_reg_final.predict(X_test)

# %% [markdown]
# g) Utvärdera modellen på testdatan.

# %%
test_results = pd.Series(
    regression_metrics(y_test, pred_test),
    name='Test set'
)
test_results
# Out:
# MAE     2.289200
# RMSE    2.976922
# Name: Test set, dtype: float64

# %% [markdown]
# h) Träna om modellen på hela datasetet.

# %%
lin_reg_final = LinearRegression().fit(X, y)

# %% [markdown]
# 10. Datasetet “salary_dataset.csv” innehåller 29 observationer av personer. YearsExperience är hur många år de arbetat, och Salary är deras lön.
#
# a) Läs in datasetet “salary_dataset.csv” med pandas read_csv()-funktion och dela upp i X och y. Avgör själv vilken variabel som ska vara den beroende variabeln y.
#
# b) Dela upp datasetet i träning- och testset. (Inget validerings-set alltså!)
#
# c) Träna två regressionsmodeller med k-delad korsvalidering med cross_validate()-funktionen från scikit-learn. Använd neg_root_mean_squared_error som scoring. Välj själv hur många iterationer den ska göra genom hyperparametern cv.
#
# d) Utvärdera modellen som presterar bäst på testsetet.
